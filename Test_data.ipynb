# %% [markdown]
# <a href="https://colab.research.google.com/github/Jittiya/Co-operative-Education-Science./blob/main/Test_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Co-operative'

# %%
data1 = pd.read_csv(os.path.join(path,'open-data-iod1.csv')) 
data1
# Out:
#   สถิติการให้บริการผู้ป่วยด้านทันตกรรมของสถาบันทันตกรรม   Unnamed: 1  \
# 0                                       การให้บริการ         ปี 2561
# 1                                                NaN      จำนวน (คน)
# 2                                                NaN             NaN
# 3                                       ในเวลาราชการ          23,042
# 4                                      นอกเวลาราชการ          18,763
# 5                                                รวม          41,805
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4              Unnamed: 5
# 0     ปี 2562     ปี 2563     ปี 2564                 ปี 2565
# 1  จำนวน (คน)  จำนวน (คน)  จำนวน (คน)  (1 ต.ค.64 - 31 พ.ค.65)
# 2         NaN         NaN         NaN              จำนวน (คน)
# 3      24,669      20,487      14,951                  14,827
# 4      19,209      15,081      15,198                  11,890
# 5      43,878      35,568      30,149                  26,717

# %%
data3 = pd.read_csv(os.path.join(path,'OS_02_0016_01.csv')) 
data3
# Out:
#       year      quarter                 region          area  \
# 0     2558  ไตรมาสที่ 1             ทั่วประเทศ           รวม
# 1     2558  ไตรมาสที่ 3  ภาคตะวันออกเฉียงเหนือ           รวม
# 2     2559  ไตรมาสที่ 2                ภาคกลาง           รวม
# 3     2559  ไตรมาสที่ 4                 ภาคใต้   ในเขตเทศบาล
# 4     2560  ไตรมาสที่ 3               ภาคเหนือ   ในเขตเทศบาล
# ...    ...          ...                    ...           ...
# 7917  2563  ไตรมาสที่ 2             ทั่วประเทศ   ในเขตเทศบาล
# 7918  2563  ไตรมาสที่ 2          กรุงเทพมหานคร   ในเขตเทศบาล
# 7919  2563  ไตรมาสที่ 2                ภาคกลาง           รวม
# 7920  2563  ไตรมาสที่ 2                ภาคกลาง   ในเขตเทศบาล
# 7921  2563  ไตรมาสที่ 2                ภาคกลาง  นอกเขตเทศบาล
#
#                        industry  value    unit                 source
# 0            ภาคเกษตรกรรม (รวม)  30.48  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 1            ภาคเกษตรกรรม (รวม)  55.72  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 2            ภาคเกษตรกรรม (รวม)  17.33  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 3            ภาคเกษตรกรรม (รวม)  18.50  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4            ภาคเกษตรกรรม (รวม)  26.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# ...                         ...    ...     ...                    ...
# 7917  นอกภาคเกษตรกรรม (ไม่ทราบ)   0.30  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 7918  นอกภาคเกษตรกรรม (ไม่ทราบ)   0.80  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 7919  นอกภาคเกษตรกรรม (ไม่ทราบ)   0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 7920  นอกภาคเกษตรกรรม (ไม่ทราบ)   0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 7921  นอกภาคเกษตรกรรม (ไม่ทราบ)   0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
#
# [7922 rows x 8 columns]

# %%
set(data3['industry'])
# Out:
# {'นอกภาคเกษตรกรรม (การก่อสร้าง)',
#  'นอกภาคเกษตรกรรม (การขนส่ง  และสถานที่เก็บสินค้า)',
#  'นอกภาคเกษตรกรรม (การขายส่ง และการขายปลีก การซ่อมแซมยานยนต์ และรถจักรยานยนต์ )',
#  'นอกภาคเกษตรกรรม (การจัดหาน้ำ การจัดการ และการบำบัดน้ำเสีย ของเสีย และสิ่งปฏิกูล)',
#  'นอกภาคเกษตรกรรม (การทำเหมืองแร่ และเหมืองหิน)',
#  'นอกภาคเกษตรกรรม (การบริหารราชการ การป้องกันประเทศและการประกันสังคมภาคบังคับ)',
#  'นอกภาคเกษตรกรรม (การผลิต)',
#  'นอกภาคเกษตรกรรม (การศึกษา)',
#  'นอกภาคเกษตรกรรม (กิจกรรมการจ้างงานในครัวเรือนส่วนบุคคล)',
#  'นอกภาคเกษตรกรรม (กิจกรรมการบริหารและการบริการสนับสนุน)',
#  'นอกภาคเกษตรกรรม (กิจกรรมขององค์การระหว่างประเทศ)',
#  'นอกภาคเกษตรกรรม (กิจกรรมด้านสุขภาพและงานสังคมสงเคราะห์)',
#  'นอกภาคเกษตรกรรม (กิจกรรมทางวิชาชีพ วิทยาศาสตร์ และเทคนิค)',
#  'นอกภาคเกษตรกรรม (กิจกรรมบริการด้านอื่น ๆ)',
#  'นอกภาคเกษตรกรรม (กิจกรรมอสังหาริมทรัพย์)',
#  'นอกภาคเกษตรกรรม (กิจการทางการเงินและการประกันภัย)',
#  'นอกภาคเกษตรกรรม (ข้อมูลข่าวสารและการสื่อสาร)',
#  'นอกภาคเกษตรกรรม (ที่พักแรม และการบริการด้านอาหาร)',
#  'นอกภาคเกษตรกรรม (รวม)',
#  'นอกภาคเกษตรกรรม (ศิลปะ ความบันเทิง และนันทนาการ)',
#  'นอกภาคเกษตรกรรม (ไฟฟ้า ก๊าซ ไอน้ำ และระบบปรับอากาศ)',
#  'นอกภาคเกษตรกรรม (ไม่ทราบ)',
#  'ภาคเกษตรกรรม (รวม)',
#  'ภาคเกษตรกรรม (เกษตรกรรม การป่าไม้ และการประมง)'}

# %%
data4 = pd.read_csv(os.path.join(path,'OS_02_0016_02.csv')) 
data4
# Out:
#       year      quarter                 region          area   level_of_edu  \
# 0     2558  ไตรมาสที่ 1             ทั่วประเทศ           รวม  ไม่มีการศึกษา
# 1     2558  ไตรมาสที่ 3  ภาคตะวันออกเฉียงเหนือ  นอกเขตเทศบาล  ไม่มีการศึกษา
# 2     2559  ไตรมาสที่ 2               ภาคเหนือ  นอกเขตเทศบาล  ไม่มีการศึกษา
# 3     2560  ไตรมาสที่ 1                ภาคกลาง   ในเขตเทศบาล  ไม่มีการศึกษา
# 4     2560  ไตรมาสที่ 4             ทั่วประเทศ  นอกเขตเทศบาล  ไม่มีการศึกษา
# ...    ...          ...                    ...           ...            ...
# 4540  2563  ไตรมาสที่ 2               ภาคเหนือ           รวม        ไม่ทราบ
# 4541  2563  ไตรมาสที่ 2               ภาคเหนือ   ในเขตเทศบาล        ไม่ทราบ
# 4542  2563  ไตรมาสที่ 2                 ภาคใต้           รวม        ไม่ทราบ
# 4543  2563  ไตรมาสที่ 2                 ภาคใต้   ในเขตเทศบาล        ไม่ทราบ
# 4544  2563  ไตรมาสที่ 2                 ภาคใต้  นอกเขตเทศบาล        ไม่ทราบ
#
#       value    unit                 source
# 0      3.32  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 1      1.14  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 2      7.52  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 3      4.60  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4      3.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# ...     ...     ...                    ...
# 4540   0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4541   0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4542   0.70  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4543   1.60  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4544   0.30  ร้อยละ  สำนักงานสถิติแห่งชาติ
#
# [4545 rows x 8 columns]

# %%
data4_cut = data4[['year','quarter','ที่อยู่จุดบริการ','ละติจูด','ลองติจูด','6 ภูมิภาค (ภูมิศาสตร์)']]  # เลือกข้อมูลที่ต้องการ
data4_cut

# %%
merged_table = data3.merge(data4,how='left',left_on='region',right_on='region')
merged_table
# Out:
#          year_x    quarter_x      region        area_x  \
# 0          2558  ไตรมาสที่ 1  ทั่วประเทศ           รวม
# 1          2558  ไตรมาสที่ 1  ทั่วประเทศ           รวม
# 2          2558  ไตรมาสที่ 1  ทั่วประเทศ           รวม
# 3          2558  ไตรมาสที่ 1  ทั่วประเทศ           รวม
# 4          2558  ไตรมาสที่ 1  ทั่วประเทศ           รวม
# ...         ...          ...         ...           ...
# 6480025    2563  ไตรมาสที่ 2     ภาคกลาง  นอกเขตเทศบาล
# 6480026    2563  ไตรมาสที่ 2     ภาคกลาง  นอกเขตเทศบาล
# 6480027    2563  ไตรมาสที่ 2     ภาคกลาง  นอกเขตเทศบาล
# 6480028    2563  ไตรมาสที่ 2     ภาคกลาง  นอกเขตเทศบาล
# 6480029    2563  ไตรมาสที่ 2     ภาคกลาง  นอกเขตเทศบาล
#
#                           industry  value_x  unit_x               source_x  \
# 0               ภาคเกษตรกรรม (รวม)    30.48  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 1               ภาคเกษตรกรรม (รวม)    30.48  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 2               ภาคเกษตรกรรม (รวม)    30.48  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 3               ภาคเกษตรกรรม (รวม)    30.48  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4               ภาคเกษตรกรรม (รวม)    30.48  ร้อยละ  สำนักงานสถิติแห่งชาติ
# ...                            ...      ...     ...                    ...
# 6480025  นอกภาคเกษตรกรรม (ไม่ทราบ)     0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480026  นอกภาคเกษตรกรรม (ไม่ทราบ)     0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480027  นอกภาคเกษตรกรรม (ไม่ทราบ)     0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480028  นอกภาคเกษตรกรรม (ไม่ทราบ)     0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480029  นอกภาคเกษตรกรรม (ไม่ทราบ)     0.10  ร้อยละ  สำนักงานสถิติแห่งชาติ
#
#          year_y    quarter_y        area_y       level_of_edu  value_y  \
# 0          2558  ไตรมาสที่ 1           รวม      ไม่มีการศึกษา     3.32
# 1          2560  ไตรมาสที่ 4  นอกเขตเทศบาล      ไม่มีการศึกษา     3.10
# 2          2560  ไตรมาสที่ 4           รวม  ต่ำกว่าประถมศึกษา    19.50
# 3          2562  ไตรมาสที่ 4   ในเขตเทศบาล  ต่ำกว่าประถมศึกษา    12.50
# 4          2561  ไตรมาสที่ 3  นอกเขตเทศบาล         ประถมศึกษา    25.30
# ...         ...          ...           ...                ...      ...
# 6480025    2563  ไตรมาสที่ 1   ในเขตเทศบาล            ไม่ทราบ     2.70
# 6480026    2563  ไตรมาสที่ 1  นอกเขตเทศบาล            ไม่ทราบ     0.80
# 6480027    2563  ไตรมาสที่ 2           รวม            ไม่ทราบ     1.30
# 6480028    2563  ไตรมาสที่ 2   ในเขตเทศบาล            ไม่ทราบ     1.60
# 6480029    2563  ไตรมาสที่ 2  นอกเขตเทศบาล            ไม่ทราบ     1.00
#
#          unit_y               source_y
# 0        ร้อยละ  สำนักงานสถิติแห่งชาติ
# 1        ร้อยละ  สำนักงานสถิติแห่งชาติ
# 2        ร้อยละ  สำนักงานสถิติแห่งชาติ
# 3        ร้อยละ  สำนักงานสถิติแห่งชาติ
# 4        ร้อยละ  สำนักงานสถิติแห่งชาติ
# ...         ...                    ...
# 6480025  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480026  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480027  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480028  ร้อยละ  สำนักงานสถิติแห่งชาติ
# 6480029  ร้อยละ  สำนักงานสถิติแห่งชาติ
#
# [6480030 rows x 15 columns]
